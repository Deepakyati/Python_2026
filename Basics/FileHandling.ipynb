# %% [markdown]
# File handling

# %%
#File Handling
#creating, reading, Updating, Deleting

# %%
#open function

a =open('fh.txt')
print(a.read())
# Out:
# #File Handling
# #creating, reading, Updating, Deleting
# #File Handling
# #creating, reading, Updating, Deleting
# #File Handling
# #creating, reading, Updating, Deleting

# %%
#Mode - '
#"r" - read
# "W" - create file or overwrite,
# "a" - Append
# "x" - 


r=open("fh.txt",'w')
r.write("Hello this is deepaj, and i am writing inside this file")
r.close()

# %%
#appending
r=open("fh.txt",'a')
r.write("Hello this is deepak, and i am appending inside this file")
r.close()

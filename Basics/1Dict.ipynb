# %% [markdown]
# Python dictionary
#
# is a data structure that stores the value in key: value pairs.
#
# Values in a dictionary can be of any data type and can be duplicated,
#
# whereas keys can't be repeated and must be immutable.

# %%
#Dictionary

d1={'name': 'Deepak', 'age':30}

print(d1)
# Out:
# {'name': 'Deepak', 'age': 30}

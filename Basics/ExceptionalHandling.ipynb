# %% [markdown]
# Exception Handling

# %%
#error

#syntax error
pritn('deepakk'
# Out:
#   Cell In[1], line 4
#     pritn('deepakk'
#                    ^
# _IncompleteInputError: incomplete input

# %%
#indentation error
a=10
if a==10:
print(a)
# Out:
#   Cell In[2], line 4
#     print(a)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
#exception
#try ->must have finally or except
#except 
#catch
#finally

# %%
a=int(input('enter a num: '))
try:
    print(10/a)
except:
    print('enter number other than 0')
# Out:
# enter number other than 0

# %%
a=int(input('enter a num: '))
try:
    print(10/a)
except ZeroDivisionError:
    print('you can not devide a num with 0')

finally:
    print('just cheking if finnaly is working or not')
# Out:
# you can not devide a num with 0
# just cheking if finnaly is working or not

# %%
#else only run if there is no exception
a=int(input('enter a num: '))
try:
    print(10/a)
except Exception as e:
    print(f'there is an error name: {e}')
else:
    print('just cheking if finnaly is working or not')
# Out:
# there is an error name: division by zero

# %%
#else only run if there is no exception
a=int(input('enter a num: '))
try:
    print(10/a)
except Exception as e:
    print(f'there is an error name: {e}')
else:
    print('just cheking if else is working or not')
# Out:
# 10.0
# just cheking if else is working or not

# %%
#finally run 

a=int(input('enter a num: '))
try:
    print(10/a)
except Exception as e:
    print(f'there is an error name: {e}')
else:
    print('just cheking if else is working or not')
finally:
    print('i will run no matter what')
# Out:
# there is an error name: division by zero
# i will run no matter what

# %%
a=int(input('enter a num: '))
try:
    print(10/a)
except Exception as e:
    print(f'there is an error name: {e}')
else:
    print('just cheking if else is working or not')
finally:
    print('i will run no matter what')
# Out:
# 10.0
# just cheking if else is working or not
# i will run no matter what

# %% [markdown]
# Raise

# %%
#Raise ->manually throws an exception

age = int(input('enter your age: '))
print(age)

if  age<10 or age>18:
    raise ValueError('age must be between 10-18')
else:
    print('welcome to the club')
print('the club will start soon')
# Out:
# 12
# welcome to the club
# the club will start soon

# %%
#Raise ->manually throws an exception

age = int(input('enter your age: '))
print(age)

if  age<10 or age>18:
    raise ValueError('age must be between 10-18')
else:
    print('welcome to the club')
print('the club will start soon')
# Out:
# 23
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       4 print(age)
#       6 if  age<10 or age>18:
# ----> 7     raise ValueError('age must be between 10-18')
#       8 else:
#       9     print('welcome to the club')
#
# ValueError: age must be between 10-18

# %%
#Raise ->manually throws an exception

age = int(input('enter your age: '))
print('age:', age)
try:
    if  age<10 or age>18:
        raise ValueError('age must be between 10-18')
    else:
        print('welcome to the club')
except Exception as e:
    print(f'an error occured: {e}')
print('the club will start soon')
# Out:
# age: 9
# an error occured: age must be between 10-18
# the club will start soon

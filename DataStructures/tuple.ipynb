# %% [markdown]
# Tuple

# %%
#immutable
#duplicates
#ordered
#Hetrogenous

# %%
a=(1,2,3,4,5)
b=[1,2,3,4,5]

print(type(a))
print(type(b))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
#tuple are immutable
a[0]=12


print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #tuple are immutable
# ----> 2 a[0]=12
#       5 print()
#
# TypeError: 'tuple' object does not support item assignment

# %%
b[0]=12 #list are mutable

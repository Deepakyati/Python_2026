# %% [markdown]
# Outliers

# %%
import numpy as np

# %%
arr = np.array([2,3,4,6,7,8,9,12,13,16,17,23,25,27,34,37,201])
arr
# Out:
# array([  2,   3,   4,   6,   7,   8,   9,  12,  13,  16,  17,  23,  25,
#         27,  34,  37, 201])

# %%
#percentile
#q1 = np.percentile(arr, 25)
q1=np.percentile(arr, 25)
q1
# Out:
# np.float64(7.0)

# %%
q2=np.percentile(arr, 50)
q2
# Out:
# np.float64(13.0)

# %%
q3=np.percentile(arr, 75)
q3
# Out:
# np.float64(25.0)

# %%
#IQR= q3 - q1

IQR = q3 - q1
IQR
# Out:
# np.float64(18.0)

# %%
#upper fence = q3 + 1.5 * IQR
upper_fence = q3 + (1.5 * IQR)
upper_fence
# Out:
# np.float64(52.0)

# %%
#lower fence = q1 - 1.5 * IQR
lower_fence = q1 - (1.5 * IQR)
lower_fence
# Out:
# np.float64(-20.0)

# %%
#removed outliers

l=[]
for i in arr:
    if i >= lower_fence and i <= upper_fence:
        l.append(i)
arr2=np.array(l)

# %%
arr2
# Out:
# array([ 2,  3,  4,  6,  7,  8,  9, 12, 13, 16, 17, 23, 25, 27, 34, 37])

# %%
#boxplot

import seaborn as sns
sns.boxplot(arr2)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.boxplot(arr2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a14c93b890>,
#   <matplotlib.lines.Line2D at 0x1a14c93b9d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a14c93bb10>,
#   <matplotlib.lines.Line2D at 0x1a14c93bc50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a14c93b750>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a14c93bd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a14c93bed0>],
#  'means': []}

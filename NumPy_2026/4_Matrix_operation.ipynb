# %% [markdown]
# Matrix Operation

# %%
import numpy as np

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
#Matrix maltiplication

A*B #but this is not how multiply occurs in Matrix
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
#first row*first coloumn

A@B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(A,B) #second method
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A.T #transpose, row became coloumn
# Out:
# array([[1, 3],
#        [2, 4]])

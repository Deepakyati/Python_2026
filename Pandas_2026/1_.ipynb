# %% [markdown]
# Use cases of Pandas
#  - Data cleaning
#  - Data analysis
#  - Data transformation
#  - Data visualization
#  - Data Aggregation
#  - File Handling
#  - Data Filtering and Selection
#  - Time Series Analysis

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_lists = [10,20,30]
my_array=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_lists)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
